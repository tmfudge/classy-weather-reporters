# %%
import sys

import cam_scrape
import weather_predictor 
from PIL import Image
import requests, os
from bs4 import BeautifulSoup as bs

# %%
path = '../Resources/testing/sunrise1.jpg'

print(weather_predictor.weather_prediction(path))
print(weather_predictor.weather_prediction(path,accuracy=True))
# Out:
# sunny
# ['sunny', 0.93061376]

# %%
url ='https://www.skylinewebcams.com/en/webcam/mexico/nuevo-leon/monterrey/panorama-de-monterrey.html'

# %%
img_url =cam_scrape.scrape_vid_loc(url)

img = requests.get(img_url).content
i=1
with open(f'test_pictures/image{i}.webp', 'wb+') as f:
    f.write(img)
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/102.0.5005.61/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\zzpie\.wdm\drivers\chromedriver\win32\102.0.5005.61]

# %%
Image.open('test_pictures/image1.webp')
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=847x477 at 0x23E81DCA280>

# %%
print(weather_predictor.weather_prediction('test_pictures/image1.webp'))
# Out:
# sunny

# %%
img
# Out:
# 'https://cdn.skylinewebcams.com/_17273600724.webp'

# %%
path = 'static/images'
pics = os.listdir(path)
picture_dic = {}
for pic in pics:
    pic_name = pic.split('.')[0]
    picture_dic[pic_name] = pic
# Out:
#   File "C:\Users\zzpie\AppData\Local\Temp/ipykernel_20088/1129993439.py", line 3
#     for pic in pics:
#                     ^
# IndentationError: expected an indented block
